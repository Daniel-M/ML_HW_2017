# %%
import datetime
import pandas as pd
from pandas_datareader import data, wb
from pandas.plotting import scatter_matrix
#old pandas
#from pandas.tools.plotting import scatter_matrix


import matplotlib.pyplot as plt
from matplotlib import style
# %matplotlib inline

# %%
start = datetime.datetime(2012, 8, 22)
end = datetime.datetime(2017, 8, 22)

# %%
df = data.DataReader("XOM", "yahoo", start, end)

# %%
df.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2012-08-22  87.199997  87.910004  87.019997  87.730003  74.929146  10160400
# 2012-08-23  87.790001  87.790001  86.980003  87.309998  74.570442   9666300
# 2012-08-24  87.160004  88.300003  86.930000  88.050003  75.202461   9762300
# 2012-08-27  88.070000  88.199997  87.610001  87.739998  74.937691   8252100
# 2012-08-28  87.570000  88.400002  87.419998  88.099998  75.245171   9646800

# %%
df.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
df.index
# Out:
# DatetimeIndex(['2012-08-22', '2012-08-23', '2012-08-24', '2012-08-27',
#                '2012-08-28', '2012-08-29', '2012-08-30', '2012-08-31',
#                '2012-09-04', '2012-09-05',
#                ...
#                '2017-08-10', '2017-08-11', '2017-08-14', '2017-08-15',
#                '2017-08-16', '2017-08-17', '2017-08-18', '2017-08-21',
#                '2017-08-22', '2017-08-23'],
#               dtype='datetime64[ns]', name='Date', length=1259, freq=None)

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1259.000000  1259.000000  1259.000000  1259.000000  1259.000000
# mean     88.276370    88.867101    87.664917    88.291509    80.843538
# std       6.749796     6.704734     6.781367     6.751962     5.294189
# min      67.989998    71.379997    66.550003    68.709999    63.966251
# 25%      83.215000    83.670002    82.560001    83.160004    77.151821
# 50%      88.269997    88.720001    87.639999    88.180000    80.252243
# 75%      92.135002    92.799999    91.569999    92.225002    84.457561
# max     104.419998   104.760002   103.949997   104.379997    93.439507
#
#              Volume
# count  1.259000e+03
# mean   1.258850e+07
# std    4.535185e+06
# min    4.156600e+06
# 25%    9.611900e+06
# 50%    1.164280e+07
# 75%    1.429040e+07
# max    4.470490e+07

# %%
style.use('fivethirtyeight')

# %%
df['High'].plot()

# %%
df.corr()
# Out:
#                Open      High       Low     Close  Adj Close    Volume
# Open       1.000000  0.996817  0.997256  0.993539   0.805640 -0.298536
# High       0.996817  1.000000  0.996468  0.997270   0.806892 -0.268193
# Low        0.997256  0.996468  1.000000  0.996739   0.809567 -0.320925
# Close      0.993539  0.997270  0.996739  1.000000   0.811592 -0.289095
# Adj Close  0.805640  0.806892  0.809567  0.811592   1.000000 -0.369337
# Volume    -0.298536 -0.268193 -0.320925 -0.289095  -0.369337  1.000000

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1259.000000  1259.000000  1259.000000  1259.000000  1259.000000
# mean     88.276370    88.867101    87.664917    88.291509    80.843538
# std       6.749796     6.704734     6.781367     6.751962     5.294189
# min      67.989998    71.379997    66.550003    68.709999    63.966251
# 25%      83.215000    83.670002    82.560001    83.160004    77.151821
# 50%      88.269997    88.720001    87.639999    88.180000    80.252243
# 75%      92.135002    92.799999    91.569999    92.225002    84.457561
# max     104.419998   104.760002   103.949997   104.379997    93.439507
#
#              Volume
# count  1.259000e+03
# mean   1.258850e+07
# std    4.535185e+06
# min    4.156600e+06
# 25%    9.611900e+06
# 50%    1.164280e+07
# 75%    1.429040e+07
# max    4.470490e+07

# %%
df.hist()
plt.show()

# %%
scatter_matrix(df)
plt.show()

# %%
df.plot.scatter('High','Low')
plt.show()

# %%
df.plot.area()
plt.show()
